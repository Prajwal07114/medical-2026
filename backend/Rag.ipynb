# %%
# !pip install langchain langchain-community langchain-huggingface langchain-groq faiss-cpu python-dotenv
# Out:
# Requirement already satisfied: langchain in c:\users\acer\baisc\annaconda\lib\site-packages (1.2.10)
# Requirement already satisfied: langchain-community in c:\users\acer\baisc\annaconda\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-huggingface in c:\users\acer\baisc\annaconda\lib\site-packages (1.2.0)
# Requirement already satisfied: langchain-groq in c:\users\acer\baisc\annaconda\lib\site-packages (1.1.2)
# Requirement already satisfied: faiss-cpu in c:\users\acer\baisc\annaconda\lib\site-packages (1.13.2)
# Requirement already satisfied: python-dotenv in c:\users\acer\baisc\annaconda\lib\site-packages (0.21.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain) (1.2.15)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain) (1.0.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-community) (0.7.6)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-community) (1.26.4)
# Collecting huggingface-hub<1.0.0,>=0.33.4 (from langchain-huggingface)
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: packaging in c:\users\acer\baisc\annaconda\lib\site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\acer\baisc\annaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\acer\baisc\annaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\acer\baisc\annaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\acer\baisc\annaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\acer\baisc\annaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: filelock in c:\users\acer\baisc\annaconda\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2024.6.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\acer\baisc\annaconda\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.66.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in c:\users\acer\baisc\annaconda\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\acer\baisc\annaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\acer\baisc\annaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\acer\baisc\annaconda\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\baisc\annaconda\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\baisc\annaconda\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\baisc\annaconda\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\acer\baisc\annaconda\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: httpcore==1.* in c:\users\acer\baisc\annaconda\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\acer\baisc\annaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\acer\baisc\annaconda\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: colorama in c:\users\acer\baisc\annaconda\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Installing collected packages: huggingface-hub
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
# Successfully installed huggingface-hub-0.36.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 5.1.0 requires huggingface-hub<2.0,>=1.3.0, but you have huggingface-hub 0.36.2 which is incompatible.

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\acer\baisc\annaconda\lib\site-packages (5.2.3)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from sentence-transformers) (5.1.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from sentence-transformers) (0.36.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: numpy in c:\users\acer\baisc\annaconda\lib\site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\acer\baisc\annaconda\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\acer\baisc\annaconda\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in c:\users\acer\baisc\annaconda\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: filelock in c:\users\acer\baisc\annaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\acer\baisc\annaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\acer\baisc\annaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\acer\baisc\annaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\acer\baisc\annaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\acer\baisc\annaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\acer\baisc\annaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\acer\baisc\annaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: colorama in c:\users\acer\baisc\annaconda\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Using cached huggingface_hub-1.4.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\acer\baisc\annaconda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer-slim in c:\users\acer\baisc\annaconda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\acer\baisc\annaconda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.27.0)
# Requirement already satisfied: shellingham in c:\users\acer\baisc\annaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: anyio in c:\users\acer\baisc\annaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: certifi in c:\users\acer\baisc\annaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\acer\baisc\annaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.2)
# Requirement already satisfied: idna in c:\users\acer\baisc\annaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: sniffio in c:\users\acer\baisc\annaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\acer\baisc\annaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\acer\baisc\annaconda\lib\site-packages (from typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.1.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\acer\baisc\annaconda\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\baisc\annaconda\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Using cached huggingface_hub-1.4.1-py3-none-any.whl (553 kB)
# Installing collected packages: huggingface-hub
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 0.36.2
#     Uninstalling huggingface_hub-0.36.2:
#       Successfully uninstalled huggingface_hub-0.36.2
# Successfully installed huggingface-hub-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-huggingface 1.2.0 requires huggingface-hub<1.0.0,>=0.33.4, but you have huggingface-hub 1.4.1 which is incompatible.

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
PDF_PATH = "Medical_book.pdf"

loader = PyPDFLoader(PDF_PATH)
documents = loader.load()

print("Total Pages:", len(documents))
print(documents[0].page_content[:500])
# Out:
# Total Pages: 637

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=150
)

splits = text_splitter.split_documents(documents)

print("Total Chunks Created:", len(splits))
print(splits[0].page_content[:500])
# Out:
# Total Chunks Created: 3282
# The GALE
# ENCYCLOPEDIA
# of MEDICINE
# SECOND EDITION

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = FAISS.from_documents(splits, embedding_model)

print("Vector Store Created Successfully!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\acer\baisc\annaconda\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:68, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      67 try:
# ---> 68     import sentence_transformers  # type: ignore[import]
#      69 except ImportError as exc:
#
# File c:\Users\acer\baisc\annaconda\Lib\site-packages\sentence_transformers\__init__.py:10
#       8 import warnings
# ---> 10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
#      15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#
# File c:\Users\acer\baisc\annaconda\Lib\site-packages\sentence_transformers\backend\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .load import load_onnx_model, load_openvino_model
#       4 from .optimize import export_optimized_onnx_model
#
# File c:\Users\acer\baisc\annaconda\Lib\site-packages\sentence_transformers\backend\load.py:7
#       5 from pathlib import Path
# ----> 7 from transformers.configuration_utils import PretrainedConfig
#       9 from sentence_transformers.backend.utils import _save_pretrained_wrapper, backend_should_export, backend_warn_to_save
#
# File c:\Users\acer\baisc\annaconda\Lib\site-packages\transformers\__init__.py:30
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#      33     _LazyModule,
#    (...)
#      40     is_pretty_midi_available,
#      41 )
#
# File c:\Users\acer\baisc\annaconda\Lib\site-packages\transformers\dependency_versions_check.py:16
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#
# File c:\Users\acer\baisc\annaconda\Lib\site-packages\transformers\utils\__init__.py:76
#      44 from .generic import (
#      45     ContextManagers,
#      46     ExplicitEnum,
#    (...)
#      74     transpose,
#      75 )
# ---> 76 from .hub import (
#      77     CHAT_TEMPLATE_DIR,
#      78     CHAT_TEMPLATE_FILE,
#      79     CLOUDFRONT_DISTRIB_PREFIX,
#      80     HF_MODULES_CACHE,
#      81     LEGACY_PROCESSOR_CHAT_TEMPLATE_FILE,
#      82     S3_BUCKET_PREFIX,
#      83     TRANSFORMERS_DYNAMIC_MODULE_NAME,
#      84     EntryNotFoundError,
#      85     PushInProgress,
#      86     PushToHubMixin,
#      87     RepositoryNotFoundError,
#      88     RevisionNotFoundError,
#      89     cached_file,
#      90     define_sagemaker_information,
#      91     extract_commit_hash,
#      92     has_file,
#      93     http_user_agent,
#      94     list_repo_templates,
#      95     try_to_load_from_cache,
#      96 )
#      97 from .import_utils import (
#      98     ACCELERATE_MIN_VERSION,
#      99     BITSANDBYTES_MIN_VERSION,
#    (...)
#     248     torch_only_method,
#     249 )
#
# File c:\Users\acer\baisc\annaconda\Lib\site-packages\transformers\utils\hub.py:29
#      28 import httpx
# ---> 29 from huggingface_hub import (
#      30     _CACHED_NO_EXIST,
#      31     CommitOperationAdd,
#      32     ModelCard,
#      33     ModelCardData,
#      34     constants,
#      35     create_branch,
#      36     create_commit,
#      37     create_repo,
#      38     hf_hub_download,
#      39     hf_hub_url,
#      40     is_offline_mode,
#      41     list_repo_tree,
#      42     snapshot_download,
#      43     try_to_load_from_cache,
#      44 )
#      45 from huggingface_hub.file_download import REGEX_COMMIT_HASH
#
# ImportError: cannot import name 'is_offline_mode' from 'huggingface_hub' (c:\Users\acer\baisc\annaconda\Lib\site-packages\huggingface_hub\__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 3
#       1 from langchain_huggingface import HuggingFaceEmbeddings
# ----> 3 embedding_model = HuggingFaceEmbeddings(
#       4     model_name="sentence-transformers/all-MiniLM-L6-v2"
#       5 )
#       7 vectorstore = FAISS.from_documents(splits, embedding_model)
#       9 print("Vector Store Created Successfully!")
#
# File c:\Users\acer\baisc\annaconda\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:74, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      69 except ImportError as exc:
#      70     msg = (
#      71         "Could not import sentence_transformers python package. "
#      72         "Please install it with `pip install sentence-transformers`."
#      73     )
# ---> 74     raise ImportError(msg) from exc
#      76 if self.model_kwargs.get("backend", "torch") == "ipex":
#      77     if not is_optimum_intel_available() or not is_ipex_available():
#
# ImportError: Could not import sentence_transformers python package. Please install it with `pip install sentence-transformers`.
